# %%
# %pip install click anthropic pymemgpt pystache~=0.6.5 openai faker~=20.1.0 colorama~=0.4.6 \
pytest time-machine==2.13.0 tiktoken~=0.5.2 goodai-ltm==0.4.4 gdown==4.7.1 tqdm \
pyyaml~=6.0.1 jinja2~=3.1.2 Werkzeug==2.2.2 flask==2.2.3 browser-cookie3 \
langchain==0.1.1 langchain-openai==0.0.2 rouge_score==0.1.2 litellm zstd==1.5.5.1 \
humanize==4.9.0 matplotlib==3.8.4 google-generativeai==0.4.1
# Out:
# Requirement already satisfied: click in ./.conda/envs/venv/lib/python3.10/site-packages (8.2.1)
# Requirement already satisfied: anthropic in ./.conda/envs/venv/lib/python3.10/site-packages (0.71.0)
# Requirement already satisfied: pymemgpt in ./.conda/envs/venv/lib/python3.10/site-packages (0.3.16)
# Requirement already satisfied: pystache~=0.6.5 in ./.conda/envs/venv/lib/python3.10/site-packages (0.6.8)
# Requirement already satisfied: openai in ./.conda/envs/venv/lib/python3.10/site-packages (1.109.1)
# Requirement already satisfied: faker~=20.1.0 in ./.conda/envs/venv/lib/python3.10/site-packages (20.1.0)
# Requirement already satisfied: colorama~=0.4.6 in ./.conda/envs/venv/lib/python3.10/site-packages (0.4.6)
# Requirement already satisfied: pytest in ./.conda/envs/venv/lib/python3.10/site-packages (9.0.2)
# Requirement already satisfied: time-machine==2.13.0 in ./.conda/envs/venv/lib/python3.10/site-packages (2.13.0)
# Requirement already satisfied: tiktoken~=0.5.2 in ./.conda/envs/venv/lib/python3.10/site-packages (0.5.2)
# Requirement already satisfied: goodai-ltm==0.4.4 in ./.conda/envs/venv/lib/python3.10/site-packages (0.4.4)
# Requirement already satisfied: gdown==4.7.1 in ./.conda/envs/venv/lib/python3.10/site-packages (4.7.1)
# Requirement already satisfied: tqdm in ./.conda/envs/venv/lib/python3.10/site-packages (4.67.1)
# Requirement already satisfied: pyyaml~=6.0.1 in ./.conda/envs/venv/lib/python3.10/site-packages (6.0.3)
# Requirement already satisfied: jinja2~=3.1.2 in ./.conda/envs/venv/lib/python3.10/site-packages (3.1.6)
# Requirement already satisfied: Werkzeug==2.2.2 in ./.conda/envs/venv/lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: flask==2.2.3 in ./.conda/envs/venv/lib/python3.10/site-packages (2.2.3)
# Requirement already satisfied: browser-cookie3 in ./.conda/envs/venv/lib/python3.10/site-packages (0.20.1)
# Requirement already satisfied: langchain==0.1.1 in ./.conda/envs/venv/lib/python3.10/site-packages (0.1.1)
# Requirement already satisfied: langchain-openai==0.0.2 in ./.conda/envs/venv/lib/python3.10/site-packages (0.0.2)
# Requirement already satisfied: rouge_score==0.1.2 in ./.conda/envs/venv/lib/python3.10/site-packages (0.1.2)
# Requirement already satisfied: litellm in ./.conda/envs/venv/lib/python3.10/site-packages (1.40.8)
# Requirement already satisfied: zstd==1.5.5.1 in ./.conda/envs/venv/lib/python3.10/site-packages (1.5.5.1)
# Requirement already satisfied: humanize==4.9.0 in ./.conda/envs/venv/lib/python3.10/site-packages (4.9.0)
# Requirement already satisfied: matplotlib==3.8.4 in ./.conda/envs/venv/lib/python3.10/site-packages (3.8.4)
# Requirement already satisfied: google-generativeai==0.4.1 in ./.conda/envs/venv/lib/python3.10/site-packages (0.4.1)
# Requirement already satisfied: python-dateutil in ./.conda/envs/venv/lib/python3.10/site-packages (from time-machine==2.13.0) (2.9.0.post0)
# Requirement already satisfied: torch>=1.8.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from goodai-ltm==0.4.4) (2.9.0)
# Requirement already satisfied: numpy>=1.19.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from goodai-ltm==0.4.4) (1.26.4)
# Requirement already satisfied: transformers>=4.34.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from goodai-ltm==0.4.4) (4.57.3)
# Requirement already satisfied: faiss-cpu in ./.conda/envs/venv/lib/python3.10/site-packages (from goodai-ltm==0.4.4) (1.13.1)
# Requirement already satisfied: datasets in ./.conda/envs/venv/lib/python3.10/site-packages (from goodai-ltm==0.4.4) (4.4.1)
# Requirement already satisfied: boto3 in ./.conda/envs/venv/lib/python3.10/site-packages (from goodai-ltm==0.4.4) (1.42.9)
# Requirement already satisfied: python-dotenv in ./.conda/envs/venv/lib/python3.10/site-packages (from goodai-ltm==0.4.4) (1.2.1)
# Requirement already satisfied: sentence-transformers>=2.2.2 in ./.conda/envs/venv/lib/python3.10/site-packages (from goodai-ltm==0.4.4) (3.1.1)
# Requirement already satisfied: FlagEmbedding>=1.1 in ./.conda/envs/venv/lib/python3.10/site-packages (from goodai-ltm==0.4.4) (1.2.11)
# Requirement already satisfied: cohere in ./.conda/envs/venv/lib/python3.10/site-packages (from goodai-ltm==0.4.4) (5.20.0)
# Requirement already satisfied: filelock in ./.conda/envs/venv/lib/python3.10/site-packages (from gdown==4.7.1) (3.20.0)
# Requirement already satisfied: requests[socks] in ./.conda/envs/venv/lib/python3.10/site-packages (from gdown==4.7.1) (2.32.5)
# Requirement already satisfied: six in ./.conda/envs/venv/lib/python3.10/site-packages (from gdown==4.7.1) (1.17.0)
# Requirement already satisfied: beautifulsoup4 in ./.conda/envs/venv/lib/python3.10/site-packages (from gdown==4.7.1) (4.14.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in ./.conda/envs/venv/lib/python3.10/site-packages (from Werkzeug==2.2.2) (3.0.3)
# Requirement already satisfied: itsdangerous>=2.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from flask==2.2.3) (2.2.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in ./.conda/envs/venv/lib/python3.10/site-packages (from langchain==0.1.1) (2.0.45)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in ./.conda/envs/venv/lib/python3.10/site-packages (from langchain==0.1.1) (3.13.2)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from langchain==0.1.1) (4.0.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in ./.conda/envs/venv/lib/python3.10/site-packages (from langchain==0.1.1) (0.6.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./.conda/envs/venv/lib/python3.10/site-packages (from langchain==0.1.1) (1.33)
# Requirement already satisfied: langchain-community<0.1,>=0.0.13 in ./.conda/envs/venv/lib/python3.10/site-packages (from langchain==0.1.1) (0.0.20)
# Requirement already satisfied: langchain-core<0.2,>=0.1.9 in ./.conda/envs/venv/lib/python3.10/site-packages (from langchain==0.1.1) (0.1.23)
# Requirement already satisfied: langsmith<0.1.0,>=0.0.77 in ./.conda/envs/venv/lib/python3.10/site-packages (from langchain==0.1.1) (0.0.87)
# Requirement already satisfied: pydantic<3,>=1 in ./.conda/envs/venv/lib/python3.10/site-packages (from langchain==0.1.1) (2.12.5)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from langchain==0.1.1) (8.5.0)
# Requirement already satisfied: absl-py in ./.conda/envs/venv/lib/python3.10/site-packages (from rouge_score==0.1.2) (2.3.1)
# Requirement already satisfied: nltk in ./.conda/envs/venv/lib/python3.10/site-packages (from rouge_score==0.1.2) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./.conda/envs/venv/lib/python3.10/site-packages (from matplotlib==3.8.4) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in ./.conda/envs/venv/lib/python3.10/site-packages (from matplotlib==3.8.4) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from matplotlib==3.8.4) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.conda/envs/venv/lib/python3.10/site-packages (from matplotlib==3.8.4) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from matplotlib==3.8.4) (23.2)
# Requirement already satisfied: pillow>=8 in ./.conda/envs/venv/lib/python3.10/site-packages (from matplotlib==3.8.4) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.conda/envs/venv/lib/python3.10/site-packages (from matplotlib==3.8.4) (3.2.5)
# Requirement already satisfied: google-ai-generativelanguage==0.4.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from google-generativeai==0.4.1) (0.4.0)
# Requirement already satisfied: google-auth>=2.15.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from google-generativeai==0.4.1) (2.43.0)
# Requirement already satisfied: google-api-core in ./.conda/envs/venv/lib/python3.10/site-packages (from google-generativeai==0.4.1) (2.28.1)
# Requirement already satisfied: protobuf in ./.conda/envs/venv/lib/python3.10/site-packages (from google-generativeai==0.4.1) (4.25.8)
# Requirement already satisfied: typing-extensions in ./.conda/envs/venv/lib/python3.10/site-packages (from google-generativeai==0.4.1) (4.15.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in ./.conda/envs/venv/lib/python3.10/site-packages (from google-ai-generativelanguage==0.4.0->google-generativeai==0.4.1) (1.26.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from openai) (4.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from openai) (0.25.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from openai) (0.12.0)
# Requirement already satisfied: sniffio in ./.conda/envs/venv/lib/python3.10/site-packages (from openai) (1.3.1)
# Requirement already satisfied: regex>=2022.1.18 in ./.conda/envs/venv/lib/python3.10/site-packages (from tiktoken~=0.5.2) (2025.11.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.1) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.1) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.1) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.conda/envs/venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.1) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.conda/envs/venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.1) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.1) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.1) (1.22.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./.conda/envs/venv/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in ./.conda/envs/venv/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain==0.1.1) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain==0.1.1) (0.9.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in ./.conda/envs/venv/lib/python3.10/site-packages (from google-api-core->google-generativeai==0.4.1) (1.72.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in ./.conda/envs/venv/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-ai-generativelanguage==0.4.0->google-generativeai==0.4.1) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in ./.conda/envs/venv/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-ai-generativelanguage==0.4.0->google-generativeai==0.4.1) (1.62.3)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from google-auth>=2.15.0->google-generativeai==0.4.1) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./.conda/envs/venv/lib/python3.10/site-packages (from google-auth>=2.15.0->google-generativeai==0.4.1) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./.conda/envs/venv/lib/python3.10/site-packages (from google-auth>=2.15.0->google-generativeai==0.4.1) (4.9.1)
# Requirement already satisfied: certifi in ./.conda/envs/venv/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in ./.conda/envs/venv/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./.conda/envs/venv/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./.conda/envs/venv/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain==0.1.1) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from pydantic<3,>=1->langchain==0.1.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in ./.conda/envs/venv/lib/python3.10/site-packages (from pydantic<3,>=1->langchain==0.1.1) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./.conda/envs/venv/lib/python3.10/site-packages (from pydantic<3,>=1->langchain==0.1.1) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.conda/envs/venv/lib/python3.10/site-packages (from requests[socks]->gdown==4.7.1) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.conda/envs/venv/lib/python3.10/site-packages (from requests[socks]->gdown==4.7.1) (2.3.0)
# Requirement already satisfied: pyasn1>=0.1.3 in ./.conda/envs/venv/lib/python3.10/site-packages (from rsa<5,>=3.1.4->google-auth>=2.15.0->google-generativeai==0.4.1) (0.6.1)
# Requirement already satisfied: greenlet>=1 in ./.conda/envs/venv/lib/python3.10/site-packages (from SQLAlchemy<3,>=1.4->langchain==0.1.1) (3.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain==0.1.1) (1.1.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in ./.conda/envs/venv/lib/python3.10/site-packages (from anthropic) (0.15)
# Requirement already satisfied: chromadb<0.5.0,>=0.4.18 in ./.conda/envs/venv/lib/python3.10/site-packages (from pymemgpt) (0.4.24)
# Requirement already satisfied: demjson3<4.0.0,>=3.0.6 in ./.conda/envs/venv/lib/python3.10/site-packages (from pymemgpt) (3.0.6)
# Requirement already satisfied: docx2txt<0.9,>=0.8 in ./.conda/envs/venv/lib/python3.10/site-packages (from pymemgpt) (0.8)
# Requirement already satisfied: html2text<2021.0.0,>=2020.1.16 in ./.conda/envs/venv/lib/python3.10/site-packages (from pymemgpt) (2020.1.16)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from pymemgpt) (0.4.0)
# Requirement already satisfied: lancedb<0.4.0,>=0.3.3 in ./.conda/envs/venv/lib/python3.10/site-packages (from pymemgpt) (0.3.6)
# Requirement already satisfied: llama-index<0.11.0,>=0.10.27 in ./.conda/envs/venv/lib/python3.10/site-packages (from pymemgpt) (0.10.68)
# Requirement already satisfied: llama-index-embeddings-azure-openai<0.2.0,>=0.1.6 in ./.conda/envs/venv/lib/python3.10/site-packages (from pymemgpt) (0.1.11)
# Requirement already satisfied: llama-index-embeddings-openai<0.2.0,>=0.1.1 in ./.conda/envs/venv/lib/python3.10/site-packages (from pymemgpt) (0.1.11)
# Requirement already satisfied: prettytable<4.0.0,>=3.9.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from pymemgpt) (3.17.0)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.2.1 in ./.conda/envs/venv/lib/python3.10/site-packages (from pymemgpt) (2.12.0)
# Requirement already satisfied: python-box<8.0.0,>=7.1.1 in ./.conda/envs/venv/lib/python3.10/site-packages (from pymemgpt) (7.3.2)
# Requirement already satisfied: python-multipart<0.0.10,>=0.0.9 in ./.conda/envs/venv/lib/python3.10/site-packages (from pymemgpt) (0.0.9)
# Requirement already satisfied: pytz<2024.0,>=2023.3.post1 in ./.conda/envs/venv/lib/python3.10/site-packages (from pymemgpt) (2023.4)
# Requirement already satisfied: questionary<3.0.0,>=2.0.1 in ./.conda/envs/venv/lib/python3.10/site-packages (from pymemgpt) (2.1.1)
# Requirement already satisfied: setuptools<69.0.0,>=68.2.2 in ./.conda/envs/venv/lib/python3.10/site-packages (from pymemgpt) (68.2.2)
# Requirement already satisfied: sqlalchemy-json<0.8.0,>=0.7.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from pymemgpt) (0.7.0)
# Requirement already satisfied: sqlalchemy-utils<0.42.0,>=0.41.2 in ./.conda/envs/venv/lib/python3.10/site-packages (from pymemgpt) (0.41.2)
# Requirement already satisfied: sqlmodel<0.0.17,>=0.0.16 in ./.conda/envs/venv/lib/python3.10/site-packages (from pymemgpt) (0.0.16)
# Requirement already satisfied: typer<0.10.0,>=0.9.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from typer[all]<0.10.0,>=0.9.0->pymemgpt) (0.9.4)
# Requirement already satisfied: build>=1.0.3 in ./.conda/envs/venv/lib/python3.10/site-packages (from chromadb<0.5.0,>=0.4.18->pymemgpt) (1.3.0)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in ./.conda/envs/venv/lib/python3.10/site-packages (from chromadb<0.5.0,>=0.4.18->pymemgpt) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in ./.conda/envs/venv/lib/python3.10/site-packages (from chromadb<0.5.0,>=0.4.18->pymemgpt) (0.124.0)
# Requirement already satisfied: uvicorn>=0.18.3 in ./.conda/envs/venv/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.18->pymemgpt) (0.38.0)
# Requirement already satisfied: posthog>=2.4.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from chromadb<0.5.0,>=0.4.18->pymemgpt) (7.0.1)
# Requirement already satisfied: pulsar-client>=3.1.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from chromadb<0.5.0,>=0.4.18->pymemgpt) (3.8.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in ./.conda/envs/venv/lib/python3.10/site-packages (from chromadb<0.5.0,>=0.4.18->pymemgpt) (1.23.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from chromadb<0.5.0,>=0.4.18->pymemgpt) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from chromadb<0.5.0,>=0.4.18->pymemgpt) (1.27.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in ./.conda/envs/venv/lib/python3.10/site-packages (from chromadb<0.5.0,>=0.4.18->pymemgpt) (0.48b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from chromadb<0.5.0,>=0.4.18->pymemgpt) (1.27.0)
# Requirement already satisfied: tokenizers>=0.13.2 in ./.conda/envs/venv/lib/python3.10/site-packages (from chromadb<0.5.0,>=0.4.18->pymemgpt) (0.22.1)
# Requirement already satisfied: pypika>=0.48.9 in ./.conda/envs/venv/lib/python3.10/site-packages (from chromadb<0.5.0,>=0.4.18->pymemgpt) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in ./.conda/envs/venv/lib/python3.10/site-packages (from chromadb<0.5.0,>=0.4.18->pymemgpt) (7.7.0)
# Requirement already satisfied: importlib-resources in ./.conda/envs/venv/lib/python3.10/site-packages (from chromadb<0.5.0,>=0.4.18->pymemgpt) (6.5.2)
# Requirement already satisfied: bcrypt>=4.0.1 in ./.conda/envs/venv/lib/python3.10/site-packages (from chromadb<0.5.0,>=0.4.18->pymemgpt) (5.0.0)
# Requirement already satisfied: kubernetes>=28.1.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from chromadb<0.5.0,>=0.4.18->pymemgpt) (34.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in ./.conda/envs/venv/lib/python3.10/site-packages (from chromadb<0.5.0,>=0.4.18->pymemgpt) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in ./.conda/envs/venv/lib/python3.10/site-packages (from chromadb<0.5.0,>=0.4.18->pymemgpt) (3.11.5)
# Requirement already satisfied: deprecation in ./.conda/envs/venv/lib/python3.10/site-packages (from lancedb<0.4.0,>=0.3.3->pymemgpt) (2.1.0)
# Requirement already satisfied: pylance==0.8.21 in ./.conda/envs/venv/lib/python3.10/site-packages (from lancedb<0.4.0,>=0.3.3->pymemgpt) (0.8.21)
# Requirement already satisfied: ratelimiter~=1.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from lancedb<0.4.0,>=0.3.3->pymemgpt) (1.2.0.post0)
# Requirement already satisfied: retry>=0.9.2 in ./.conda/envs/venv/lib/python3.10/site-packages (from lancedb<0.4.0,>=0.3.3->pymemgpt) (0.9.2)
# Requirement already satisfied: semver>=3.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from lancedb<0.4.0,>=0.3.3->pymemgpt) (3.0.4)
# Requirement already satisfied: pyarrow>=10 in ./.conda/envs/venv/lib/python3.10/site-packages (from pylance==0.8.21->lancedb<0.4.0,>=0.3.3->pymemgpt) (22.0.0)
# Requirement already satisfied: llama-index-agent-openai<0.3.0,>=0.1.4 in ./.conda/envs/venv/lib/python3.10/site-packages (from llama-index<0.11.0,>=0.10.27->pymemgpt) (0.2.9)
# Requirement already satisfied: llama-index-cli<0.2.0,>=0.1.2 in ./.conda/envs/venv/lib/python3.10/site-packages (from llama-index<0.11.0,>=0.10.27->pymemgpt) (0.1.13)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.68 in ./.conda/envs/venv/lib/python3.10/site-packages (from llama-index<0.11.0,>=0.10.27->pymemgpt) (0.10.68.post1)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.2.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from llama-index<0.11.0,>=0.10.27->pymemgpt) (0.2.7)
# Requirement already satisfied: llama-index-legacy<0.10.0,>=0.9.48 in ./.conda/envs/venv/lib/python3.10/site-packages (from llama-index<0.11.0,>=0.10.27->pymemgpt) (0.9.48.post4)
# Requirement already satisfied: llama-index-llms-openai<0.2.0,>=0.1.27 in ./.conda/envs/venv/lib/python3.10/site-packages (from llama-index<0.11.0,>=0.10.27->pymemgpt) (0.1.31)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.2.0,>=0.1.3 in ./.conda/envs/venv/lib/python3.10/site-packages (from llama-index<0.11.0,>=0.10.27->pymemgpt) (0.1.9)
# Requirement already satisfied: llama-index-program-openai<0.2.0,>=0.1.3 in ./.conda/envs/venv/lib/python3.10/site-packages (from llama-index<0.11.0,>=0.10.27->pymemgpt) (0.1.7)
# Requirement already satisfied: llama-index-question-gen-openai<0.2.0,>=0.1.2 in ./.conda/envs/venv/lib/python3.10/site-packages (from llama-index<0.11.0,>=0.10.27->pymemgpt) (0.1.3)
# Requirement already satisfied: llama-index-readers-file<0.2.0,>=0.1.4 in ./.conda/envs/venv/lib/python3.10/site-packages (from llama-index<0.11.0,>=0.10.27->pymemgpt) (0.1.33)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.1.2 in ./.conda/envs/venv/lib/python3.10/site-packages (from llama-index<0.11.0,>=0.10.27->pymemgpt) (0.1.6)
# Requirement already satisfied: deprecated>=1.2.9.3 in ./.conda/envs/venv/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.68->llama-index<0.11.0,>=0.10.27->pymemgpt) (1.3.1)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in ./.conda/envs/venv/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.68->llama-index<0.11.0,>=0.10.27->pymemgpt) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.68->llama-index<0.11.0,>=0.10.27->pymemgpt) (2025.10.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in ./.conda/envs/venv/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.68->llama-index<0.11.0,>=0.10.27->pymemgpt) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.68->llama-index<0.11.0,>=0.10.27->pymemgpt) (3.4.2)
# Requirement already satisfied: pandas in ./.conda/envs/venv/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.68->llama-index<0.11.0,>=0.10.27->pymemgpt) (2.3.3)
# Requirement already satisfied: wrapt in ./.conda/envs/venv/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.68->llama-index<0.11.0,>=0.10.27->pymemgpt) (1.17.3)
# Requirement already satisfied: llama-index-llms-azure-openai<0.2.0,>=0.1.3 in ./.conda/envs/venv/lib/python3.10/site-packages (from llama-index-embeddings-azure-openai<0.2.0,>=0.1.6->pymemgpt) (0.1.10)
# Requirement already satisfied: azure-identity<2.0.0,>=1.15.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from llama-index-llms-azure-openai<0.2.0,>=0.1.3->llama-index-embeddings-azure-openai<0.2.0,>=0.1.6->pymemgpt) (1.25.1)
# Requirement already satisfied: azure-core>=1.31.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai<0.2.0,>=0.1.3->llama-index-embeddings-azure-openai<0.2.0,>=0.1.6->pymemgpt) (1.37.0)
# Requirement already satisfied: cryptography>=2.5 in ./.conda/envs/venv/lib/python3.10/site-packages (from azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai<0.2.0,>=0.1.3->llama-index-embeddings-azure-openai<0.2.0,>=0.1.6->pymemgpt) (46.0.3)
# Requirement already satisfied: msal>=1.30.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai<0.2.0,>=0.1.3->llama-index-embeddings-azure-openai<0.2.0,>=0.1.6->pymemgpt) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai<0.2.0,>=0.1.3->llama-index-embeddings-azure-openai<0.2.0,>=0.1.6->pymemgpt) (1.3.1)
# Requirement already satisfied: pypdf<5.0.0,>=4.0.1 in ./.conda/envs/venv/lib/python3.10/site-packages (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index<0.11.0,>=0.10.27->pymemgpt) (4.3.1)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in ./.conda/envs/venv/lib/python3.10/site-packages (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index<0.11.0,>=0.10.27->pymemgpt) (0.0.26)
# Requirement already satisfied: soupsieve>=1.6.1 in ./.conda/envs/venv/lib/python3.10/site-packages (from beautifulsoup4->gdown==4.7.1) (2.8)
# Requirement already satisfied: wcwidth in ./.conda/envs/venv/lib/python3.10/site-packages (from prettytable<4.0.0,>=3.9.0->pymemgpt) (0.2.14)
# Requirement already satisfied: prompt_toolkit<4.0,>=2.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from questionary<3.0.0,>=2.0.1->pymemgpt) (3.0.52)
# Requirement already satisfied: shellingham<2.0.0,>=1.3.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from typer[all]<0.10.0,>=0.9.0->pymemgpt) (1.5.4)
# Requirement already satisfied: rich<14.0.0,>=10.11.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from typer[all]<0.10.0,>=0.9.0->pymemgpt) (13.9.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from rich<14.0.0,>=10.11.0->typer[all]<0.10.0,>=0.9.0->pymemgpt) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from rich<14.0.0,>=10.11.0->typer[all]<0.10.0,>=0.9.0->pymemgpt) (2.19.2)
# Requirement already satisfied: iniconfig>=1.0.1 in ./.conda/envs/venv/lib/python3.10/site-packages (from pytest) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in ./.conda/envs/venv/lib/python3.10/site-packages (from pytest) (1.6.0)
# Requirement already satisfied: tomli>=1 in ./.conda/envs/venv/lib/python3.10/site-packages (from pytest) (2.3.0)
# Requirement already satisfied: lz4 in ./.conda/envs/venv/lib/python3.10/site-packages (from browser-cookie3) (4.4.5)
# Requirement already satisfied: pycryptodomex in ./.conda/envs/venv/lib/python3.10/site-packages (from browser-cookie3) (3.23.0)
# Requirement already satisfied: jeepney in ./.conda/envs/venv/lib/python3.10/site-packages (from browser-cookie3) (0.9.0)
# Requirement already satisfied: importlib-metadata>=6.8.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from litellm) (8.4.0)
# Requirement already satisfied: pyproject_hooks in ./.conda/envs/venv/lib/python3.10/site-packages (from build>=1.0.3->chromadb<0.5.0,>=0.4.18->pymemgpt) (1.2.0)
# Requirement already satisfied: cffi>=2.0.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from cryptography>=2.5->azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai<0.2.0,>=0.1.3->llama-index-embeddings-azure-openai<0.2.0,>=0.1.6->pymemgpt) (2.0.0)
# Requirement already satisfied: pycparser in ./.conda/envs/venv/lib/python3.10/site-packages (from cffi>=2.0.0->cryptography>=2.5->azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai<0.2.0,>=0.1.3->llama-index-embeddings-azure-openai<0.2.0,>=0.1.6->pymemgpt) (2.23)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from fastapi>=0.95.2->chromadb<0.5.0,>=0.4.18->pymemgpt) (0.50.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in ./.conda/envs/venv/lib/python3.10/site-packages (from fastapi>=0.95.2->chromadb<0.5.0,>=0.4.18->pymemgpt) (0.0.4)
# Requirement already satisfied: accelerate>=0.20.1 in ./.conda/envs/venv/lib/python3.10/site-packages (from FlagEmbedding>=1.1->goodai-ltm==0.4.4) (1.12.0)
# Requirement already satisfied: psutil in ./.conda/envs/venv/lib/python3.10/site-packages (from accelerate>=0.20.1->FlagEmbedding>=1.1->goodai-ltm==0.4.4) (7.1.3)
# Requirement already satisfied: huggingface_hub>=0.21.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from accelerate>=0.20.1->FlagEmbedding>=1.1->goodai-ltm==0.4.4) (0.36.0)
# Requirement already satisfied: safetensors>=0.4.3 in ./.conda/envs/venv/lib/python3.10/site-packages (from accelerate>=0.20.1->FlagEmbedding>=1.1->goodai-ltm==0.4.4) (0.7.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in ./.conda/envs/venv/lib/python3.10/site-packages (from huggingface_hub>=0.21.0->accelerate>=0.20.1->FlagEmbedding>=1.1->goodai-ltm==0.4.4) (1.2.0)
# Requirement already satisfied: zipp>=0.5 in ./.conda/envs/venv/lib/python3.10/site-packages (from importlib-metadata>=6.8.0->litellm) (3.23.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.18->pymemgpt) (1.9.0)
# Requirement already satisfied: requests-oauthlib in ./.conda/envs/venv/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.18->pymemgpt) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in ./.conda/envs/venv/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.18->pymemgpt) (0.10)
# Requirement already satisfied: llama-cloud>=0.0.11 in ./.conda/envs/venv/lib/python3.10/site-packages (from llama-index-indices-managed-llama-cloud>=0.2.0->llama-index<0.11.0,>=0.10.27->pymemgpt) (0.1.45)
# Requirement already satisfied: llama-parse>=0.4.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from llama-index-readers-llama-parse>=0.1.2->llama-index<0.11.0,>=0.10.27->pymemgpt) (0.4.9)
# Requirement already satisfied: mdurl~=0.1 in ./.conda/envs/venv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=10.11.0->typer[all]<0.10.0,>=0.9.0->pymemgpt) (0.1.2)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai<0.2.0,>=0.1.3->llama-index-embeddings-azure-openai<0.2.0,>=0.1.6->pymemgpt) (2.10.1)
# Requirement already satisfied: joblib in ./.conda/envs/venv/lib/python3.10/site-packages (from nltk->rouge_score==0.1.2) (1.5.2)
# Requirement already satisfied: coloredlogs in ./.conda/envs/venv/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.18->pymemgpt) (15.0.1)
# Requirement already satisfied: flatbuffers in ./.conda/envs/venv/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.18->pymemgpt) (25.9.23)
# Requirement already satisfied: sympy in ./.conda/envs/venv/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.18->pymemgpt) (1.14.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.27.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<0.5.0,>=0.4.18->pymemgpt) (1.27.0)
# Requirement already satisfied: opentelemetry-proto==1.27.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<0.5.0,>=0.4.18->pymemgpt) (1.27.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.48b0 in ./.conda/envs/venv/lib/python3.10/site-packages (from opentelemetry-sdk>=1.2.0->chromadb<0.5.0,>=0.4.18->pymemgpt) (0.48b0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.48b0 in ./.conda/envs/venv/lib/python3.10/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.18->pymemgpt) (0.48b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.48b0 in ./.conda/envs/venv/lib/python3.10/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.18->pymemgpt) (0.48b0)
# Requirement already satisfied: opentelemetry-util-http==0.48b0 in ./.conda/envs/venv/lib/python3.10/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.18->pymemgpt) (0.48b0)
# Requirement already satisfied: asgiref~=3.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from opentelemetry-instrumentation-asgi==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.18->pymemgpt) (3.11.0)
# Requirement already satisfied: backoff>=1.10.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from posthog>=2.4.0->chromadb<0.5.0,>=0.4.18->pymemgpt) (2.2.1)
# Requirement already satisfied: decorator>=3.4.2 in ./.conda/envs/venv/lib/python3.10/site-packages (from retry>=0.9.2->lancedb<0.4.0,>=0.3.3->pymemgpt) (5.2.1)
# Requirement already satisfied: py<2.0.0,>=1.4.26 in ./.conda/envs/venv/lib/python3.10/site-packages (from retry>=0.9.2->lancedb<0.4.0,>=0.3.3->pymemgpt) (1.11.0)
# Requirement already satisfied: scikit-learn in ./.conda/envs/venv/lib/python3.10/site-packages (from sentence-transformers>=2.2.2->goodai-ltm==0.4.4) (1.7.2)
# Requirement already satisfied: scipy in ./.conda/envs/venv/lib/python3.10/site-packages (from sentence-transformers>=2.2.2->goodai-ltm==0.4.4) (1.15.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in ./.conda/envs/venv/lib/python3.10/site-packages (from torch>=1.8.0->goodai-ltm==0.4.4) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in ./.conda/envs/venv/lib/python3.10/site-packages (from torch>=1.8.0->goodai-ltm==0.4.4) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in ./.conda/envs/venv/lib/python3.10/site-packages (from torch>=1.8.0->goodai-ltm==0.4.4) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in ./.conda/envs/venv/lib/python3.10/site-packages (from torch>=1.8.0->goodai-ltm==0.4.4) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in ./.conda/envs/venv/lib/python3.10/site-packages (from torch>=1.8.0->goodai-ltm==0.4.4) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in ./.conda/envs/venv/lib/python3.10/site-packages (from torch>=1.8.0->goodai-ltm==0.4.4) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in ./.conda/envs/venv/lib/python3.10/site-packages (from torch>=1.8.0->goodai-ltm==0.4.4) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in ./.conda/envs/venv/lib/python3.10/site-packages (from torch>=1.8.0->goodai-ltm==0.4.4) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in ./.conda/envs/venv/lib/python3.10/site-packages (from torch>=1.8.0->goodai-ltm==0.4.4) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in ./.conda/envs/venv/lib/python3.10/site-packages (from torch>=1.8.0->goodai-ltm==0.4.4) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in ./.conda/envs/venv/lib/python3.10/site-packages (from torch>=1.8.0->goodai-ltm==0.4.4) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in ./.conda/envs/venv/lib/python3.10/site-packages (from torch>=1.8.0->goodai-ltm==0.4.4) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in ./.conda/envs/venv/lib/python3.10/site-packages (from torch>=1.8.0->goodai-ltm==0.4.4) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in ./.conda/envs/venv/lib/python3.10/site-packages (from torch>=1.8.0->goodai-ltm==0.4.4) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in ./.conda/envs/venv/lib/python3.10/site-packages (from torch>=1.8.0->goodai-ltm==0.4.4) (1.13.1.3)
# Requirement already satisfied: triton==3.5.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from torch>=1.8.0->goodai-ltm==0.4.4) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from sympy->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.18->pymemgpt) (1.3.0)
# Requirement already satisfied: httptools>=0.6.3 in ./.conda/envs/venv/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.18->pymemgpt) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in ./.conda/envs/venv/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.18->pymemgpt) (0.22.1)
# Requirement already satisfied: watchfiles>=0.13 in ./.conda/envs/venv/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.18->pymemgpt) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in ./.conda/envs/venv/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.18->pymemgpt) (15.0.1)
# Requirement already satisfied: botocore<1.43.0,>=1.42.9 in ./.conda/envs/venv/lib/python3.10/site-packages (from boto3->goodai-ltm==0.4.4) (1.42.9)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in ./.conda/envs/venv/lib/python3.10/site-packages (from boto3->goodai-ltm==0.4.4) (1.0.1)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from boto3->goodai-ltm==0.4.4) (0.16.0)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in ./.conda/envs/venv/lib/python3.10/site-packages (from cohere->goodai-ltm==0.4.4) (1.12.1)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from cohere->goodai-ltm==0.4.4) (2.32.4.20250913)
# Requirement already satisfied: humanfriendly>=9.1 in ./.conda/envs/venv/lib/python3.10/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.18->pymemgpt) (10.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from datasets->goodai-ltm==0.4.4) (0.4.0)
# Requirement already satisfied: xxhash in ./.conda/envs/venv/lib/python3.10/site-packages (from datasets->goodai-ltm==0.4.4) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in ./.conda/envs/venv/lib/python3.10/site-packages (from datasets->goodai-ltm==0.4.4) (0.70.18)
# Requirement already satisfied: tzdata>=2022.7 in ./.conda/envs/venv/lib/python3.10/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.68->llama-index<0.11.0,>=0.10.27->pymemgpt) (2025.2)
# Requirement already satisfied: oauthlib>=3.0.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.18->pymemgpt) (3.3.1)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in ./.conda/envs/venv/lib/python3.10/site-packages (from requests[socks]->gdown==4.7.1) (1.7.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from scikit-learn->sentence-transformers>=2.2.2->goodai-ltm==0.4.4) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys, os
sys.path.insert(0, "goodai-ltm-benchmark")

from dataclasses import dataclass
from typing import List, Tuple
import pystache
from dataset_interfaces.interface import DatasetInterface, TestExample

COLOURS = [
    "Red",
    "White",
    "Blue",
    "Green",
    "Yellow",
    "Pink",
    "Magenta",
    "Cyan",
    "Purple",
    "Tan",
    "Khaki",
    "Beige",
    "Cream",
    "Brown",
    "Olive",
    # "None",
]

STATEMENTS = [
    "My favourite colour is {{colour}}.",
    "{{colour}} is my favourite colour.",
    "My favourite colour could be described as {{colour}}.",
    "The name of my favourite colour is {{colour}}.",
]


@dataclass
class ColourDataset(DatasetInterface):
    name: str = "Colours"
    description: str = "Tell the agent what your favourite colour is multiple time, then ask it what that colour is."
    question: str = "What is my favourite colour?"
    colour_changes: int = 3
    memory_span: int = 100 

    def generate_examples(self, num_examples):
        examples = []

        for _ in range(num_examples):
            is_question = []
            colours = []
            script = []
            renderer = pystache.Renderer()

            for change in range(self.colour_changes):
                colour = self.random.choice(COLOURS)
                if colour == "None":
                    name_stmt = "I have no favourite colour."
                else:
                    name_stmt = renderer.render(self.random.choice(STATEMENTS), {"colour": colour})
                colours.append(colour)
                script.append(name_stmt)
                is_question.append(False)

            script.append(self.question)
            is_question.append(True)
            answer_list = [colours[-1]]
            example = TestExample(
                dataset_generator=self,
                script=script,
                expected_responses=answer_list,
                is_question=is_question,
            )
            examples.append(example)

        return examples

    def evaluate_correct(
        self, questions: List[str], responses: List[str], expected_answers: List[str]
    ) -> Tuple[int, int, List[str]]:
        color = expected_answers[0].lower()
        if color in responses[-1].lower():
            return 1, 1, [f'"{color}" is in the response.']
        return 0, 1, [f'"{color}" is NOT in the response.']

# %%
# Initialize the dataset
dataset = ColourDataset()
examples = dataset.generate_examples(num_examples=200)  # adjust number as needed

# Collect all sentences to translate
lines = []
for ex in examples:
    lines.extend(ex.script)

# Collect the correct answers
answers = []
for ex in examples:
    answers.extend(ex.expected_responses)

# Save example sentences to a txt file
with open("test/colours_sentences.txt", "w") as f:
    for line in lines:
        clean_line = line.strip()
        f.write(clean_line + "\n")

# Save example answers to a txt file
with open("test/colours_answers.txt", "w") as f:
    for answer in answers:
        clean_answer = answer.strip()
        f.write(answer + "\n")

print(f"Saved {len(lines)} sentences to test/colours_sentences.txt")
print(f"Saved {len(answers)} answers to test/colours_answers.txt")
# Out:
# Saved 800 sentences to test/colours_sentences.txt
# Saved 200 answers to test/colours_answers.txt
